# %%
import os
import pickle
import pandas as pd
import numpy as np
from sklearn import linear_model
#from sklearn.externals import joblib
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-22-efbd5c0fa1b9> in <module>
#       4 import numpy as np
#       5 from sklearn import linear_model
# ----> 6 from sklearn.externals import joblib
#
# ImportError: cannot import name 'joblib' from 'sklearn.externals' (C:\Users\dphil\Miniconda3\envs\codebasics\lib\site-packages\sklearn\externals\__init__.py)

# %%
# Set path to csv
homeprices_path = os.path.join("2_linear_regression", "homeprices.csv")
df = pd.read_csv(homeprices_path)
df.head()
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
model = linear_model.LinearRegression()
model.fit(df[['area']], df.price)
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([135.78767123])

# %%
model.intercept_
# Out:
# 180616.43835616432

# %%
model.predict([[5000]])
# Out:
# array([859554.79452055])

# %%
# Enter x
x = 5000

# Find y_predicted
y_predicted = model.coef_ * x + model.intercept_

# Print results
print(f"${round(float(y_predicted[0]),2)}")
# Out:
# $859554.79

# %%
with open('model_pickle', 'wb') as f:
    pickle.dump(model, f)

# %%
with open('model_pickle', 'rb') as f:
    mp = pickle.load(f)

# %%
mp.predict([[5000]])
# Out:
# array([859554.79452055])
